# %%
import pandas as pd
import cobra
import numpy as np
import matplotlib.pyplot as plt
import json

# %% [markdown]
# # Community modeling
#
# In this notebook we will implement a method to create community models of two or more species specific metabolic models using cobrapy.

# %%
model_DP = cobra.io.read_sbml_model("models/consistent_DP_SNM.xml")
model_SA = cobra.io.read_sbml_model("models/consistent_iYS854_SNM.xml")
print("Growth: ", model_DP.slim_optimize())
print("Growth: ", model_SA.slim_optimize())
# Out:
# Growth:  0.2823653925322476
# Growth:  2.558694612613393

# %%
Des = pd.read_csv("Descriptive_name.csv", sep =";")

# %%
snm3 = pd.read_csv("SNM3.csv", sep =";")
snm3
# Out:
#                  Compound     BiGG ModelSeed    KEGG
# 0                 Alanine   ala__L  cpd00035  C00041
# 1                Arginine   arg__L  cpd00051  C00062
# 2                Cysteine   cys__L  cpd00084  C00097
# 3           Glutamic acid   glu__L  cpd00023  C00025
# 4                 Glycine      gly  cpd00033  C00037
# 5               Histidine   his__L  cpd00119  C00135
# 6                 Leucine   leu__L  cpd00107  C00123
# 7                  Lysine   lys__L  cpd00039  C00047
# 8               Ornithine      orn  cpd00064  C00077
# 9           Phenylalanine   phe__L  cpd00066  C00079
# 10                Proline   pro__L  cpd00129  C00148
# 11                 Serine   ser__L  cpd00054  C00065
# 12              Threonine   thr__L  cpd00161  C00188
# 13            Tryptophane   trp__L  cpd00065  C00078
# 14                 Valine   val__L  cpd00156  C00183
# 15            citric acid      cit  cpd00137  C00158
# 16           Fumaric acid      fum  cpd00106  C00122
# 17            maleic acid     male  cpd00996  C01384
# 18           pyruvic acid      pyr  cpd00020  C00022
# 19          succinic acid     succ  cpd00036  C00042
# 20                glucose   glc__D  cpd00027  C00031
# 21                   Urea     urea  cpd00073  C00086
# 22                 Sodium      na1  cpd00971  C01330
# 23               Chloride       cl  cpd00099  C00698
# 24              Potassium        k  cpd00205  C00238
# 25              Phosphate       pi  cpd00009  C00009
# 26              Magnesium      mg2  cpd00254  C00305
# 27               Sulphate      so4  cpd00048  C00059
# 28        2,2'-Bipyridine      NaN  cpd25442     NaN
# 29                Calcium      ca2  cpd00063  C00076
# 30                  ZnCl2      zn2  cpd00034  C00038
# 31                  MnCl2      mn2  cpd00030  C00034
# 32                  H3BO3      NaN  cpd09225  C12486
# 33                  CoCl2  cobalt2  cpd00149  C00175
# 34                  CuCl2      cu2  cpd00058  C00070
# 35                  NiCl2      ni2  cpd00244  C00291
# 36                MoNa2O4     mobd  cpd11574  C06232
# 37        Cyanocobalamine   adocbl  cpd01826  C02823
# 38    p-Aminobenzoic acid     4abz  cpd00443  C00568
# 39                 Biotin      btn  cpd00104  C00120
# 40         Nicotinic acid      nac  cpd00218  C00253
# 41  Ca-D-Pantothenic acid  pnto__R  cpd00644  C00864
# 42      Pyridoxamine-2HCl    pydam  cpd00419  C00534
# 43    Thiamine-dichloride      thm  cpd00305  C00378
# 44             Riboflavin   ribflv  cpd00220  C00255
# 45                 Oxygen       o2  cpd00007  C00007
# 46                   Fe3+      fe2  cpd10516  C14819
# 47                  Water      h2o  cpd00001  C00001
# 48                    Co2      co2  cpd00011  C00011

# %%
BIOMASS_DP = "Growth" 
BIOMASS_SA = "BIOMASS_iYS_wild_type"
models = [model_DP.copy(), model_SA.copy()]

# %%
ex_DP_ids = set(map(lambda x:x.id, model_DP.exchanges))
ex_SA_ids = set(map(lambda x:x.id, model_SA.exchanges))
ex_union_ids = ex_DP_ids.union(ex_SA_ids)
print("Number of united exchange reactions: ", len(ex_union_ids))
# Out:
# Number of united exchange reactions:  111

# %%
fva_DP = cobra.flux_analysis.flux_variability_analysis(model_DP)
fva_SA = cobra.flux_analysis.flux_variability_analysis(model_SA)

# %%
U =[]
for ex in ex_union_ids:
    if ex in fva_DP.index and ex in fva_SA.index:
        U.append(ex_union_ids)

# %%
len(U)
# Out:
# 36

# %%
def compute_exchange(fva_DP, fva_SA):
    media_exchange_DP = dict()
    media_exchange_SA = dict()
    for ex in ex_union_ids:
        if ex in fva_DP.index and ex in fva_SA.index:
            if not (fva_DP.loc[ex].minimum ==0 and fva_DP.loc[ex].maximum == 0):
                if not (fva_SA.loc[ex].minimum ==0 and fva_SA.loc[ex].maximum == 0):
                    flux = - 10
                    if flux < 0:
                        media_exchange_DP[ex] = abs(flux)
                        media_exchange_SA[ex] = abs(flux)
        elif ex in fva_DP.index:
            # Take just the minimum if not common
            flux = fva_DP.loc[ex].minimum
            if flux < 0:
                media_exchange_DP[ex] = abs(flux)
        elif ex in fva_SA.index:
            # Take just the minimum if not common
            flux = fva_SA.loc[ex].minimum
            if flux < 0:
                media_exchange_SA[ex] = abs(flux)
        else:
            print("error")
    return media_exchange_DP, media_exchange_SA

# %%
media_exchange_DP, media_exchange_SA = compute_exchange(fva_DP,fva_SA)

# %%
def save_dict(data, name):
    with open(name, 'w' ) as file:
        json.dump( data, file )

# %%
print("Length of media: ", len(media_exchange_DP))
print(media_exchange_DP)
save_dict(media_exchange_DP, "exchange_DP.json")
# Out:
# Length of media:  44
# {'EX_thr__L_e': 0.06937020546135564, 'EX_pi_e': 10, 'EX_co2_e': 10, 'EX_met__L_e': 10, 'EX_4abz_e': 0.00018293671908059108, 'EX_lys__L_e': 10, 'EX_glc__D_e': 10, 'EX_cl_e': 10, 'EX_ile__L_e': 10, 'EX_val__L_e': 10, 'EX_orn_e': 10, 'EX_zn2_e': 10, 'EX_gly_e': 10.0, 'EX_mn2_e': 10, 'EX_fum_e': 10.0, 'EX_phe__L_e': 10, 'EX_glyclt_e': 10, 'EX_k_e': 10, 'EX_tyr__L_e': 10, 'EX_cobalt2_e': 0.009981830860061667, 'EX_so4_e': 10, 'EX_nh4_e': 10, 'EX_cys__L_e': 10, 'EX_ni2_e': 0.010022613010017837, 'EX_leu__L_e': 10, 'EX_pro__L_e': 0.06044704997960771, 'EX_o2_e': 10, 'EX_nac_e': 10, 'EX_ala__L_e': 10.0, 'EX_fe2_e': 10, 'EX_ca2_e': 0.01467790893862432, 'EX_trp__L_e': 10, 'EX_h_e': 10, 'EX_ribflv_e': 10, 'EX_na1_e': 10, 'EX_acald_e': 10, 'EX_glu__L_e': 10, 'EX_h2o_e': 10, 'EX_arg__L_e': 10, 'EX_his__L_e': 10, 'EX_cu2_e': 0.009257250408242637, 'EX_26dap__M_e': 0.027344801057605284, 'EX_thm_e': 10, 'EX_mg2_e': 10}

# %%
print("Length of media: ", len(media_exchange_SA))
print(media_exchange_SA)
save_dict(media_exchange_SA, "exchange_SA.json")
# Out:
# Length of media:  37
# {'EX_pi_e': 10, 'EX_co2_e': 10, 'EX_met__L_e': 10, 'EX_lys__L_e': 10, 'EX_glc__D_e': 10, 'EX_cl_e': 10, 'EX_ile__L_e': 10, 'EX_val__L_e': 10, 'EX_orn_e': 10, 'EX_zn2_e': 10, 'EX_mn2_e': 10, 'EX_phe__L_e': 10, 'EX_mobd_e': 1.791086228829375e-05, 'EX_glyclt_e': 10, 'EX_k_e': 10, 'EX_tyr__L_e': 10, 'EX_so4_e': 10, 'EX_nh4_e': 10, 'EX_cys__L_e': 10, 'EX_leu__L_e': 10, 'EX_o2_e': 10, 'EX_nac_e': 10, 'EX_fe2_e': 10, 'EX_trp__L_e': 10, 'EX_h_e': 10, 'EX_ribflv_e': 10, 'EX_na1_e': 10, 'EX_acald_e': 10, 'EX_glu__L_e': 10, 'EX_h2o_e': 10, 'EX_arg__L_e': 10, 'EX_his__L_e': 10, 'EX_ser__L_e': 10.0, 'EX_pyr_e': 10.0, 'EX_thm_e': 10, 'EX_urea_e': 10.0, 'EX_mg2_e': 10}

# %% [markdown]
# ## 1) Constructing of a compartment community model
# We will costruct a community model as following:
# * We will name each non-exchange reaction and associated metabolites or compartments by: id + model_id, where model_id is the identifier of the model. Thus cobra will consider them as seperate systems.
# * We will add the exchange metabolites and reactions unchanged as the envirionment as they should be shared by both models! We define the set of all exchange reactions as the union of the single set.

# %%
def modify_reaction_id(rec, id):
    # Mark reaktion by organism id, copy all attributes
    new_reaction = cobra.Reaction(rec.id + id)
    new_reaction.name = rec.name 
    new_reaction.subsystem = rec.subsystem
    new_reaction.lower_bound = rec.lower_bound
    new_reaction.upper_bound = rec.upper_bound
    # Create new metabolites for reaction
    metabolites = rec.metabolites
    new_mets = dict()
    for met, val in metabolites.items(): 
        # Reaction should be copied, but assign metabilites to organism by id
        comp = met.compartment 
        if comp != "e":
            # If it is not an exchanged metabolite, assign id
            new_met = cobra.Metabolite(met.id + id, formula=met.formula, name=met.name, compartment=comp + id)
        else:
            # If it is an exchange metabolite, then do not assign id
            new_met = cobra.Metabolite(met.id, formula=met.formula, name=met.name, compartment=comp)
        new_mets[new_met] = val # Same stoichimetry
    new_reaction.add_metabolites(new_mets)
    new_reaction.gene_reaction_rule = rec.gene_reaction_rule
    try:
        # This does not work for every reactions...
        new_reaction.genes = rec.genes
    except:
        pass
    return new_reaction

# %%
def create_community_model(models, biomass_functions, weights = "auto", medium="auto"):
    """ This methods builds a community model given a list of single models. 

    It does this by renaming all metabolites/reactions with species specific ids  """
    ids = [model.id for model in models]
    model_id = "community_" +"__".join([model.id for model in models])
    model = cobra.Model("Community model")
    for model_i in models:
        id = "_" + model_i.id
        reactions = model_i.reactions.copy()
        new_reactions = []
        for rec in reactions:
            if "EX_" in rec.id:
                # Add exchange reactions unchanged -> Shared by organisms!
                if not rec in model.exchanges:
                    model.add_reactions([rec])
            else:
                # Modify reactions that they are recognized as different.
                new_reaction = modify_reaction_id(rec,id)
                new_reactions.append(new_reaction)
        model.add_reactions(new_reactions)
    # Compute weights: Such that all models have same growth on their medium!
    if weights == "auto":
        biomass = []
        for model_i in models:
            biomass.append(model_i.slim_optimize())
        max_biomass = np.max(biomass)
        weights = [max_biomass/g for g in biomass]
    
    # Set objective as sum of growth
    objective = []
    for i, growth in enumerate(biomass_functions):
        v_i = weights[i] * model.reactions.get_by_id(growth + "_" + ids[i]).flux_expression
        objective.append(v_i)
    model.objective = sum(objective)
    if medium=="auto":
        # Set medium to union of model mediums
        medium = dict()
        for m in models:
            for key ,val in m.medium.items():
                medium[key] = val
        model.medium = medium 
    else:
        model.medium = medium

    return model

# %% [markdown]
# ## Investigate Exchange
#
# The medium should induce competition!

# %%
import json
exchange_SA = json.loads(open("exchange_SA.json").read())
exchange_DP = json.loads(open("exchange_DP.json").read())

# %%
exchange = dict()
for key, val in exchange_SA.items():
    exchange[key] = val 
for key, val in exchange_DP.items():
    exchange[key] = val

# %%
model = create_community_model(models, [BIOMASS_DP, BIOMASS_SA], weights=[1.,1.], medium=exchange)
# Out:
# There are no boundary reactions in this model. Therefore specific types of boundary reactions such as 'exchanges', 'demands' or 'sinks' cannot be identified.

# %%
model.medium = exchange

# %%
opt = model.optimize()
print("SA growth: " + str(model.reactions.get_by_id(BIOMASS_SA + "_" + model_SA.id).flux))
print("DP growth: " + str(model.reactions.get_by_id(BIOMASS_DP + "_" + model_DP.id).flux))
# Out:
# SA growth: 2.558694612613393
# DP growth: 0.28236539253378184

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth_DP_83VPs_KB5 + 1.0 BIOMASS_iYS_wild_type_iYS854 = 2.841060005147175</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>26dap__M_e</td>
#       <td>EX_26dap__M_e</td>
#       <td>0.02734</td>
#       <td>7</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>4abz_e</td>
#       <td>EX_4abz_e</td>
#       <td>0.0001829</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>acald_e</td>
#       <td>EX_acald_e</td>
#       <td>10</td>
#       <td>2</td>
#       <td>5.82%</td>
#     </tr>
#     <tr>
#       <td>ala__L_e</td>
#       <td>EX_ala__L_e</td>
#       <td>0.05902</td>
#       <td>3</td>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <td>arg__L_e</td>
#       <td>EX_arg__L_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>17.47%</td>
#     </tr>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.01468</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.02926</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>0.009982</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.009257</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cys__L_e</td>
#       <td>EX_cys__L_e</td>
#       <td>0.7566</td>
#       <td>3</td>
#       <td>0.66%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.05883</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>17.47%</td>
#     </tr>
#     <tr>
#       <td>glu__L_e</td>
#       <td>EX_glu__L_e</td>
#       <td>10</td>
#       <td>5</td>
#       <td>14.56%</td>
#     </tr>
#     <tr>
#       <td>gly_e</td>
#       <td>EX_gly_e</td>
#       <td>0.2819</td>
#       <td>2</td>
#       <td>0.16%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td
td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mql8_c_DP_83VPs_KB5</td>
#       <td>Sink_mql8_DP_83VPs_KB5</td>
#       <td>2.734E-05</td>
#       <td>51</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5drib_c_iYS854</td>
#       <td>DM_5drib_c_iYS854</td>
#       <td>-0.002303</td>
#       <td>5</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>amob_c_iYS854</td>
#       <td>DM_amob_c_iYS854</td>
#       <td>-5.117E-06</td>
#       <td>15</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_e</td>
#       <td>-10.11</td>
#       <td>2</td>
#       <td>8.34%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-70.21</td>
#       <td>1</td>
#       <td>28.96%</td>
#     </tr>
#     <tr>
#       <td>etoh_e</td>
#       <td>EX_etoh_e</td>
#       <td>-30.65</td>
#       <td>2</td>
#       <td>25.29%</td>
#     </tr>
#     <tr>
#       <td>for_e</td>
#       <td>EX_for_e</td>
#       <td>-19.03</td>
#       <td>1</td>
#       <td>7.85%</td>
#     </tr>
#     <tr>
#       <td>fum_e</td>
#       <td>EX_fum_e</td>
#       <td>-0.09337</td>
#       <td>4</td>
#       <td>0.15%</td>
#     </tr>
#     <tr>
#       <td>glyclt_e</td>
#       <td>EX_glyclt_e</td>
#       <td>-0.001324</td>
#       <td>2</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2s_e</td>
#       <td>EX_h2s_e</td>
#       <td>-0.4759</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>-46.66</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ptrc_e</td>
#       <td>EX_ptrc_e</td>
#       <td>-17.78<

# %%
x1 =[]
y1 =[]
z1 =[]
for met, f in model.medium.items():
    with model:
        medium = model.medium 
        medium[met] = 0
        model.medium = medium
        model.optimize()
        print(met)
        print("SA growth: " + str(model.reactions.get_by_id(BIOMASS_SA + "_" + model_SA.id).flux))
        print("DP growth: " + str(model.reactions.get_by_id(BIOMASS_DP + "_" + model_DP.id).flux))
        for j in range(len(Des)):
            ide = "EX_" + str(Des.iloc[j][1]) + "_e"
            if met == ide:
                x1.append(str(Des.iloc[j][0]))
                y1.append(round(model.reactions.get_by_id(BIOMASS_SA + "_" + model_SA.id).flux,3))
                z1.append(round(model.reactions.get_by_id(BIOMASS_DP + "_" + model_DP.id).flux,3))
# Out:
# EX_glc__D_e
# SA growth: 2.331197520298228
# DP growth: 0.0
# EX_h2o_e
# SA growth: 2.558694612613393
# DP growth: 0.2688293502063436
# EX_h_e
# SA growth: 2.558694612613393
# DP growth: 0.28236539253378184
# EX_leu__L_e
# SA growth: 2.558694612613393
# DP growth: 0.28104301872293586
# EX_4abz_e
# SA growth: 2.558694612613393
# DP growth: 0.0
# EX_ala__L_e
# SA growth: 2.558694612613393
# DP growth: 0.28236539253378184
# EX_cl_e
# SA growth: 0.0
# DP growth: 0.0
# EX_acald_e
# SA growth: 2.558694612613393
# DP growth: 0.2688293502063445
# EX_pi_e
# SA growth: 2.558694612613393
# DP growth: 0.27434144182834247
# EX_ribflv_e
# SA growth: 2.558694612613393
# DP growth: 0.28236539253378184
# EX_nh4_e
# SA growth: 2.558694612613393
# DP growth: 0.28236539253378184
# EX_gly_e
# SA growth: 2.558694612613393
# DP growth: 0.21802794979430484
# EX_thr__L_e
# SA growth: 2.558694612613393
# DP growth: 0.0
# EX_arg__L_e
# SA growth: 2.558694612613393
# DP growth: 0.24778395119642052
# EX_lys__L_e
# SA growth: 2.558694612613393
# DP growth: 0.2590265899074953
# EX_orn_e
# SA growth: 2.558694612613393
# DP growth: 0.26523665833368476
# EX_k_e
# SA growth: 0.0
# DP growth: 0.0
# EX_pro__L_e
# SA growth: 2.558694612613393
# DP growth: 0.0
# EX_ca2_e
# SA growth: 2.558694612613393
# DP growth: 0.0
# EX_mg2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_mn2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_cobalt2_e
# SA growth: 2.558694612613393
# DP growth: 0.0
# EX_zn2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_co2_e
# SA growth: 2.558694612613393
# DP growth: 0.28236539253224924
# EX_cu2_e
# SA growth: 2.558694612613393
# DP growth: 0.0
# EX_o2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_glu__L_e
# SA growth: 2.558694612613393
# DP growth: 0.23809701966462854
# EX_fe2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_fum_e
# SA growth: 2.558694612613393
# DP growth: 0.28236539253378184
# EX_glyclt_e
# SA growth: 2.558694612613393
# DP growth: 0.28236539253378184
# EX_his__L_e
# SA growth: 2.558694612613393
# DP growth: 0.27710319484783
# EX_ile__L_e
# SA growth: 2.558694612613393
# DP growth: 0.25945605653501713
# EX_met__L_e
# SA growth: 2.558694612613393
# DP growth: 0.2823016084996154
# EX_so4_e
# SA growth: 0.0
# DP growth: 0.0
# EX_trp__L_e
# SA growth: 2.558694612613393
# DP growth: 0.27896627141132957
# EX_val__L_e
# SA growth: 2.558694612613393
# DP growth: 0.2751316825638008
# EX_thm_e
# SA growth: 0.0
# DP growth: 0.0
# EX_cys__L_e
# SA growth: 0.0
# DP growth: 0.0
# EX_phe__L_e
# SA growth: 2.558694612613393
# DP growth: 0.26514924561326353
# EX_na1_e
# SA growth: 0.0
# DP growth: 0.0
# EX_ni2_e
# SA growth: 2.558694612613393
# DP growth: 0.0
# EX_nac_e
# SA growth: 0.0
# DP growth: 0.0
# EX_26dap__M_e
# SA growth: 2.558694612613393
# DP growth: 0.0
# EX_tyr__L_e
# SA growth: 2.558694612613393
# DP growth: 0.2790837393289044
# EX_mobd_e
# SA growth: 0.0
# DP growth: 0.28236539253378184
# EX_pyr_e
# SA growth: 2.558694612613393
# DP growth: 0.256682157029962
# EX_ser__L_e
# SA growth: 2.558694612613393
# DP growth: 0.23578444120199896
# EX_urea_e
# SA growth: 2.558694612613393
# DP growth: 0.25890670848835257

# %%
model = create_community_model(models, [BIOMASS_DP, BIOMASS_SA], weights=[10.,1.], medium=exchange)
# Out:
# There are no boundary reactions in this model. Therefore specific types of boundary reactions such as 'exchanges', 'demands' or 'sinks' cannot be identified.

# %%
opt = model.optimize()
print("SA growth: " + str(model.reactions.get_by_id(BIOMASS_SA + "_" + model_SA.id).flux))
print("DP growth: " + str(model.reactions.get_by_id(BIOMASS_DP + "_" + model_DP.id).flux))
# Out:
# SA growth: 2.5626440286853414
# DP growth: 0.28236539253224924

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>10.0 Growth_DP_83VPs_KB5 + 1.0 BIOMASS_iYS_wild_type_iYS854 = 5.3862979540078335</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td
td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>thr__L_e</td>
#       <td>EX_thr__L_e</td>
#       <td>0.06937</td>
#       <td>4</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>trp__L_e</td>
#       <td>EX_trp__L_e</td>
#       <td>0.05485</td>
#       <td>11</td>
#       <td>0.17%</td>
#     </tr>
#     <tr>
#       <td>tyr__L_e</td>
#       <td>EX_tyr__L_e</td>
#       <td>0.2332</td>
#       <td>9</td>
#       <td>0.59%</td>
#     </tr>
#     <tr>
#       <td>urea_e</td>
#       <td>EX_urea_e</td>
#       <td>10</td>
#       <td>1</td>
#       <td>2.81%</td>
#     </tr>
#     <tr>
#       <td>val__L_e</td>
#       <td>EX_val__L_e</td>
#       <td>1.059</td>
#       <td>5</td>
#       <td>1.49%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>0.009824</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>2fe1s_c_iYS854</td>
#       <td>SK_2fe1s_c_iYS854</td>
#       <td>0.0006996</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>apoACP_c_iYS854</td>
#       <td>SK_apoACP_c_iYS854</td>
#       <td>0.1972</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mql8_c_DP_83VPs_KB5</td>
#       <td>Sink_mql8_DP_83VPs_KB5</td>
#       <td>2.734E-05</td>
#       <td>51</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5drib_c_iYS854</td>
#       <td>DM_5drib_c_iYS854</td>
#       <td>-0.002306</td>
#       <td>5</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>amob_c_iYS854</td>
#       <td>DM_amob_c_iYS854</td>
#       <td>-5.125E-06</td>
#       <td>15</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_e</td>
#       <td>-10.13</td>
#       <td>2</td>
#       <td>7.97%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-71.24</td>
#       <td>1</td>
#       <td>28.02%</td>
#     </tr>
#     <tr>
#       <td>etoh_e</td>
#       <td>EX_etoh_e</td>
#       <td>-31.83</td>
#       <td>2</td>
#       <td>25.04%</td>
#     </tr>
#     <tr>
#       <td>for_e</td>
#       <td>EX_for_e</td>
#       <td>-22.04</td>
#       <td>1</td>
#       <td>8.67%</td>
#     </tr>
#     <tr>
#       <td>glyclt_e</td>
#       <td>EX_glyclt_e</td>
#       <td>-0.001326</td>
#       <td>2</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2s_e</td>
#       <td>EX_h2s_e</td>
#       <td>-0.4759</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>-45.26</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ptrc_e</td>
#       <td>EX_ptrc_e</td>
#       <td>-17.78</td>

# %%
x2 =[]
y2 =[]
z2 =[]
for met, f in model.medium.items():
    with model:
        medium = model.medium 
        medium[met] = 0
        model.medium = medium
        model.optimize()
        print(met)
        print("SA growth: " + str(model.reactions.get_by_id(BIOMASS_SA + "_" + model_SA.id).flux))
        print("DP growth: " + str(model.reactions.get_by_id(BIOMASS_DP + "_" + model_DP.id).flux))
        for j in range(len(Des)):
            ide = "EX_" + str(Des.iloc[j][1]) + "_e"
            if met == ide:
                x2.append(str(Des.iloc[j][0]))
                y2.append(round(model.reactions.get_by_id(BIOMASS_SA + "_" + model_SA.id).flux,3))
                z2.append(round(model.reactions.get_by_id(BIOMASS_DP + "_" + model_DP.id).flux,3))
# Out:
# EX_glc__D_e
# SA growth: 2.3311975202982316
# DP growth: 0.0
# EX_h2o_e
# SA growth: 2.4651028829458377
# DP growth: 0.28236539253378184
# EX_h_e
# SA growth: 2.5626440286747147
# SA growth: 2.2557784618914534
# DP growth: 0.28236539253378184
# EX_urea_e
# SA growth: 2.3955087532179484
# DP growth: 0.28236539253378184

# %%
# Draw plot
title_font = {'fontname':'Arial', 'size':'12', 'color':'black', 'weight':'normal'} 
fig = plt.figure(figsize=(10,5), dpi= 160)

plt.scatter(x = x1, y = y1, color="darkgoldenrod",s=5, marker="^")
plt.scatter(x = x1, y = z1, color="green",s=3, marker="o")
plt.scatter(x = x2, y = y2, color="darkgoldenrod",s=40, marker="^")
plt.scatter(x = x2, y = z2, color="green",s=20, marker="o")
plt.ylim(-0.2,6)     
plt.legend(["$\it{S.aureus}$ with weight 1:1" , "$\it{D. pigrum}$ with weight 1:1", "$\it{S.aureus}$ with weight 1:10" , "$\it{D. pigrum}$ with weight 1:10"], loc=8, bbox_to_anchor=(0.5, 0.6))

# Decorations    
plt.title('The effect of removing each single metabolite from the integrated community on the growth with exchange media', **title_font)

plt.xticks(x1,rotation=90)
plt.grid(linestyle='--', alpha=0.5)
plt.ylabel("Growth of $\it{S.aureus}$ and $\it{D. pigrum}$ in the community")
#fig.tight_layout()

plt.savefig("Integrated_community_remove_metabolite_growth_effect_media_exchange.pdf", bbox_inches='tight', dpi=1000) 
plt.show()

# %%
len(x1)
# Out:
# 48

# %%
len(x2)
# Out:
# 48

# %%
exchange
# Out:
# {'EX_pi_e': 10,
#  'EX_co2_e': 10,
#  'EX_met__L_e': 10,
#  'EX_lys__L_e': 10,
#  'EX_glc__D_e': 10,
#  'EX_cl_e': 10,
#  'EX_ile__L_e': 10,
#  'EX_val__L_e': 10,
#  'EX_orn_e': 10,
#  'EX_zn2_e': 10,
#  'EX_mn2_e': 10,
#  'EX_phe__L_e': 10,
#  'EX_mobd_e': 1.791086228829375e-05,
#  'EX_glyclt_e': 10,
#  'EX_k_e': 10,
#  'EX_tyr__L_e': 10,
#  'EX_so4_e': 10,
#  'EX_nh4_e': 10,
#  'EX_cys__L_e': 10,
#  'EX_leu__L_e': 10,
#  'EX_o2_e': 10,
#  'EX_nac_e': 10,
#  'EX_fe2_e': 10,
#  'EX_trp__L_e': 10,
#  'EX_h_e': 10,
#  'EX_ribflv_e': 10,
#  'EX_na1_e': 10,
#  'EX_acald_e': 10,
#  'EX_glu__L_e': 10,
#  'EX_h2o_e': 10,
#  'EX_arg__L_e': 10,
#  'EX_his__L_e': 10,
#  'EX_ser__L_e': 10.0,
#  'EX_pyr_e': 10.0,
#  'EX_thm_e': 10,
#  'EX_urea_e': 10.0,
#  'EX_mg2_e': 10,
#  'EX_thr__L_e': 0.06937020546135564,
#  'EX_4abz_e': 0.00018293671908059108,
#  'EX_gly_e': 10.0,
#  'EX_fum_e': 10.0,
#  'EX_cobalt2_e': 0.009981830860061667,
#  'EX_ni2_e': 0.010022613010017837,
#  'EX_pro__L_e': 0.06044704997960771,
#  'EX_ala__L_e': 10.0,
#  'EX_ca2_e': 0.01467790893862432,
#  'EX_cu2_e': 0.009257250408242637,
#  'EX_26dap__M_e': 0.027344801057605284}
