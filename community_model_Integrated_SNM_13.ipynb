# %%
import pandas as pd
import cobra
import numpy as np
import matplotlib.pyplot as plt
import json

# %% [markdown]
# # Community modeling
#
# In this notebook we will implement a method to create community models of two or more species specific metabolic models using cobrapy.

# %%
model_DP = cobra.io.read_sbml_model("models/consistent_DP_SNM.xml")
model_SA = cobra.io.read_sbml_model("models/consistent_iYS854_SNM.xml")
print("Growth: ", model_DP.slim_optimize())
print("Growth: ", model_SA.slim_optimize())
# Out:
# Growth:  0.2823653925322476
# Growth:  2.558694612613393

# %%
Des = pd.read_csv("Descriptive_name.csv", sep =";")

# %%
snm3 = pd.read_csv("SNM3.csv", sep =";")
snm3
# Out:
#                  Compound     BiGG ModelSeed    KEGG
# 0                 Alanine   ala__L  cpd00035  C00041
# 1                Arginine   arg__L  cpd00051  C00062
# 2                Cysteine   cys__L  cpd00084  C00097
# 3           Glutamic acid   glu__L  cpd00023  C00025
# 4                 Glycine      gly  cpd00033  C00037
# 5               Histidine   his__L  cpd00119  C00135
# 6                 Leucine   leu__L  cpd00107  C00123
# 7                  Lysine   lys__L  cpd00039  C00047
# 8               Ornithine      orn  cpd00064  C00077
# 9           Phenylalanine   phe__L  cpd00066  C00079
# 10                Proline   pro__L  cpd00129  C00148
# 11                 Serine   ser__L  cpd00054  C00065
# 12              Threonine   thr__L  cpd00161  C00188
# 13            Tryptophane   trp__L  cpd00065  C00078
# 14                 Valine   val__L  cpd00156  C00183
# 15            citric acid      cit  cpd00137  C00158
# 16           Fumaric acid      fum  cpd00106  C00122
# 17            maleic acid     male  cpd00996  C01384
# 18           pyruvic acid      pyr  cpd00020  C00022
# 19          succinic acid     succ  cpd00036  C00042
# 20                glucose   glc__D  cpd00027  C00031
# 21                   Urea     urea  cpd00073  C00086
# 22                 Sodium      na1  cpd00971  C01330
# 23               Chloride       cl  cpd00099  C00698
# 24              Potassium        k  cpd00205  C00238
# 25              Phosphate       pi  cpd00009  C00009
# 26              Magnesium      mg2  cpd00254  C00305
# 27               Sulphate      so4  cpd00048  C00059
# 28        2,2'-Bipyridine      NaN  cpd25442     NaN
# 29                Calcium      ca2  cpd00063  C00076
# 30                  ZnCl2      zn2  cpd00034  C00038
# 31                  MnCl2      mn2  cpd00030  C00034
# 32                  H3BO3      NaN  cpd09225  C12486
# 33                  CoCl2  cobalt2  cpd00149  C00175
# 34                  CuCl2      cu2  cpd00058  C00070
# 35                  NiCl2      ni2  cpd00244  C00291
# 36                MoNa2O4     mobd  cpd11574  C06232
# 37        Cyanocobalamine   adocbl  cpd01826  C02823
# 38    p-Aminobenzoic acid     4abz  cpd00443  C00568
# 39                 Biotin      btn  cpd00104  C00120
# 40         Nicotinic acid      nac  cpd00218  C00253
# 41  Ca-D-Pantothenic acid  pnto__R  cpd00644  C00864
# 42      Pyridoxamine-2HCl    pydam  cpd00419  C00534
# 43    Thiamine-dichloride      thm  cpd00305  C00378
# 44             Riboflavin   ribflv  cpd00220  C00255
# 45                 Oxygen       o2  cpd00007  C00007
# 46                   Fe3+      fe2  cpd10516  C14819
# 47                  Water      h2o  cpd00001  C00001
# 48                    Co2      co2  cpd00011  C00011

# %%
BIOMASS_DP = "Growth" 
BIOMASS_SA = "BIOMASS_iYS_wild_type"
models = [model_DP.copy(), model_SA.copy()]

# %% [markdown]
# ## 1) Constructing of a compartment community model
# We will costruct a community model as following:
# * We will name each non-exchange reaction and associated metabolites or compartments by: id + model_id, where model_id is the identifier of the model. Thus cobra will consider them as seperate systems.
# * We will add the exchange metabolites and reactions unchanged as the envirionment as they should be shared by both models! We define the set of all exchange reactions as the union of the single set.

# %%
def modify_reaction_id(rec, id):
    # Mark reaktion by organism id, copy all attributes
    new_reaction = cobra.Reaction(rec.id + id)
    new_reaction.name = rec.name 
    new_reaction.subsystem = rec.subsystem
    new_reaction.lower_bound = rec.lower_bound
    new_reaction.upper_bound = rec.upper_bound
    # Create new metabolites for reaction
    metabolites = rec.metabolites
    new_mets = dict()
    for met, val in metabolites.items(): 
        # Reaction should be copied, but assign metabilites to organism by id
        comp = met.compartment 
        if comp != "e":
            # If it is not an exchanged metabolite, assign id
            new_met = cobra.Metabolite(met.id + id, formula=met.formula, name=met.name, compartment=comp + id)
        else:
            # If it is an exchange metabolite, then do not assign id
            new_met = cobra.Metabolite(met.id, formula=met.formula, name=met.name, compartment=comp)
        new_mets[new_met] = val # Same stoichimetry
    new_reaction.add_metabolites(new_mets)
    new_reaction.gene_reaction_rule = rec.gene_reaction_rule
    try:
        # This does not work for every reactions...
        new_reaction.genes = rec.genes
    except:
        pass
    return new_reaction

# %%
def create_community_model(models, biomass_functions, weights = "auto", medium="auto"):
    """ This methods builds a community model given a list of single models. 

    It does this by renaming all metabolites/reactions with species specific ids  """
    ids = [model.id for model in models]
    model_id = "community_" +"__".join([model.id for model in models])
    model = cobra.Model("Community model")
    for model_i in models:
        id = "_" + model_i.id
        reactions = model_i.reactions.copy()
        new_reactions = []
        for rec in reactions:
            if "EX_" in rec.id:
                # Add exchange reactions unchanged -> Shared by organisms!
                if not rec in model.exchanges:
                    model.add_reactions([rec])
            else:
                # Modify reactions that they are recognized as different.
                new_reaction = modify_reaction_id(rec,id)
                new_reactions.append(new_reaction)
        model.add_reactions(new_reactions)
    # Compute weights: Such that all models have same growth on their medium!
    if weights == "auto":
        biomass = []
        for model_i in models:
            biomass.append(model_i.slim_optimize())
        max_biomass = np.max(biomass)
        weights = [max_biomass/g for g in biomass]
    
    # Set objective as sum of growth
    objective = []
    for i, growth in enumerate(biomass_functions):
        v_i = weights[i] * model.reactions.get_by_id(growth + "_" + ids[i]).flux_expression
        objective.append(v_i)
    model.objective = sum(objective)
    if medium=="auto":
        # Set medium to union of model mediums
        medium = dict()
        for m in models:
            for key ,val in m.medium.items():
                medium[key] = val
        model.medium = medium 
    else:
        model.medium = medium

    return model

# %% [markdown]
# ## Investigate SNM3 medium
#
# The medium should induce competition!

# %%
model = create_community_model(models, [BIOMASS_DP, BIOMASS_SA], weights=[1.,1.])
# Out:
# There are no boundary reactions in this model. Therefore specific types of boundary reactions such as 'exchanges', 'demands' or 'sinks' cannot be identified.

# %%
opt = model.optimize()
print("SA growth: " + str(model.reactions.get_by_id(BIOMASS_SA + "_" + model_SA.id).flux))
print("DP growth: " + str(model.reactions.get_by_id(BIOMASS_DP + "_" + model_DP.id).flux))
# Out:
# SA growth: 5.025290140091366
# DP growth: 0.02411460929043585

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth_DP_83VPs_KB5 + 1.0 BIOMASS_iYS_wild_type_iYS854 = 5.049404749381802</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>26dap__M_e</td>
#       <td>EX_26dap__M_e</td>
#       <td>0.002335</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>4abz_e</td>
#       <td>EX_4abz_e</td>
#       <td>1.562E-05</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ala__L_e</td>
#       <td>EX_ala__L_e</td>
#       <td>10</td>
#       <td>3</td>
#       <td>6.76%</td>
#     </tr>
#     <tr>
#       <td>arg__L_e</td>
#       <td>EX_arg__L_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>13.51%</td>
#     </tr>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.001254</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.0263</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>0.0008525</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.0007906</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cys__L_e</td>
#       <td>EX_cys__L_e</td>
#       <td>10</td>
#       <td>3</td>
#       <td>6.76%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.07596</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fum_e</td>
#       <td>EX_fum_e</td>
#       <td>10</td>
#       <td>4</td>
#       <td>9.01%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>13.51%</td>
#     </tr>
#     <tr>
#       <td>glu__L_e</td>
#       <td>EX_glu__L_e</td>
#       <td>10</td>
#       <td>5</td>
#       <td>11.26%</td>
#     </tr>
#     <tr>
#       <td>gly_e</td>
#       <td>EX_gly_e</td>
#       <td>0.03517</td>
#       <td>2</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>his__L_e</td>
#       <td>EX_his__L_e</td>
#       <td>0.305</td>
#       <td>6</td>
#       <td>0.41%</td>
#     </tr>
#     <tr>
#       <td>ile__L_e</td>
#       <td>EX_ile__L_e</td>
#       <td>1.633</td>
#       <td>6</td>
#       <td>2.21%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.9344</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>leu__L_e</td>
#       <td>EX_leu__L_e</td>
#       <td>1.589</td>
#       <td>6</td>
#       <td>2.15%</td>
#     </tr>
#     <tr>
#       <td>lys__L_e</td>
#       <td>EX_lys__L_e</td>
#       <td>1.82</td>
#       <td>6</td>
#       <td>2.46%</td>
#     </tr>
#     <tr>
#       <td>met__L_e</td>
#       <td>EX_met__L_e</td>
#       <td>0.4105</td>
#       <td>5</td>
#       <td>0.46%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.04354</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>0.004221</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mobd_e</td>
#       <td>EX_mobd_e</td>
#       <td>3.518E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nac_e</td>
#       <td>EX_nac_e</td>
#       <td>0.0007119</td>
#       <td>6</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ni2_e</td>
#       <td>EX_ni2_e</td>
#       <td>0.000856</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>20</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>orn_e</td>
#       <td>EX_orn_e</td>
#       <td>10</td>
#       <td>5</td>
#       <td>11.26%</td>
#     </tr>
#     <tr>
#       <td>phe__L_e</td>
#       <td>EX_phe__L_e</td>
#       <td>0.9653</td>
#       <td>9</td>
#       <td>1.96%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pro__L_e</td>
#       <td>EX_pro__L_e</td>
#       <td>0.005162</td>
#       <td>5</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>pyr_e</td>
#       <td>EX_pyr_e</td>
#       <td>10</td>
#       <td>3</td>
#       <td>6.76%</td>
#     </tr>
#     <tr>
#       <td>ribflv_e</td>
#       <td>EX_ribflv_e</td>
#       <td>0.00151</td>
#       <td>17</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>ser__L_e</td>
#       <td>EX_ser__L_e</td>
#       <td>10</td>
#       <td>3</td>
#       <td>6.76%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.02126</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>thm_e</td>
#       <td>EX_thm_e</td>
#       <td>0.002246</td>
#       <td>12</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>thr__L_e</td>
#       <td>EX_thr__L_e</td>
#       <td>0.005924</td>
#       <td>4</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>trp__L_e</td>
#       <td>EX_trp__L_e</td>
#       <td>0.07842</td>
#       <td>11</td>
#       <td>0.19%</td>
#     </tr>
#     <tr>
#       <td>urea_e</td>
#       <td>EX_urea_e</td>
#       <td>10</td>
#       <td>1</td>
#       <td>2.25%</td>
#     </tr>
#     <tr>
#       <td>val__L_e</td>
#       <td>EX_val__L_e</td>
#       <td>2.023</td>
#       <td>5</td>
#       <td>2.28%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>0.002396</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>2fe1s_c_iYS854</td>
#       <td>SK_2fe1s_c_iYS854</td>
#       <td>0.001372</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>apoACP_c_iYS854</td>
#       <td>SK_apoACP_c_iYS854</td>
#       <td>0.3867</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mql8_c_DP_83VPs_KB5</td>
#       <td>Sink_mql8_DP_83VPs_KB5</td>
#       <td>2.335E-06</td>
#       <td>51</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5drib_c_iYS854</td>
#       <td>DM_5drib_c_iYS854</td>
#       <td>-0.004523</td>
#       <td>5</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>amob_c_iYS854</td>
#       <td>DM_amob_c_iYS854</td>
#       <td>-1.005E-05</td>
#       <td>15</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-102.2</td>
#       <td>1</td>
#       <td>38.22%</td>
#     </tr>
#     <tr>
#       <td>etoh_e</td>
#       <td>EX_etoh_e</td>
#       <td>-52.04</td>
#       <td>2</td>
#       <td>38.92%</td>
#     </tr>
#     <tr>
#       <td>for_e</td>
#       <td>EX_for_e</td>
#       <td>-21.58</td>
#       <td>1</td>
#       <td>8.07%</td>
#     </tr>
#     <tr>
#       <td>glyclt_e</td>
#       <td>EX_glyclt_e</td>
#       <td>-0.002257</td>
#       <td>2</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2s_e</td>
#       <td>EX_h2s_e</td>
#       <td>-9.499</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>-68.11</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ptrc_e</td>
#       <td>EX_ptrc_e</td>
#       <td>-9.801</td>
#       <td>4</td>
#       <td>14.66%</td>
#     </tr>
#     <tr>
#       <td>ahcys_c_iYS854</td>
#       <td>SK_ahcys_c_iYS854</td>
#       <td>-0.02482</td>
#       <td>14</td>
#       <td>0.13%</td>
#     </tr>
#   </tbody>
# </table>

# %%
x1 =[]
y1 =[]
z1 =[]
for met, f in model.medium.items():
    with model:
        medium = model.medium 
        medium[met] = 0
        model.medium = medium
        model.optimize()
        print(met)
        print("SA growth: " + str(model.reactions.get_by_id(BIOMASS_SA + "_" + model_SA.id).flux))
        print("DP growth: " + str(model.reactions.get_by_id(BIOMASS_DP + "_" + model_DP.id).flux))
        for j in range(len(Des)):
            ide = "EX_" + str(Des.iloc[j][1]) + "_e"
            if ide == met:
                x1.append(str(Des.iloc[j][0]))
                y1.append(round(model.reactions.get_by_id(BIOMASS_SA + "_" + model_SA.id).flux,3))
                z1.append(round(model.reactions.get_by_id(BIOMASS_DP + "_" + model_DP.id).flux,3))
# Out:
# EX_glc__D_e
# SA growth: 3.141874771171119
# DP growth: 0.0
# EX_h2o_e
# SA growth: 4.980558865988176
# DP growth: 0.0
# EX_leu__L_e
# SA growth: 5.025846357878463
# DP growth: 0.011903231142710524
# EX_4abz_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_ala__L_e
# SA growth: 5.025290140091338
# DP growth: 0.02411460929106113
# EX_cl_e
# SA growth: 0.0
# DP growth: 0.0
# EX_pi_e
# SA growth: 4.9805588659881685
# DP growth: 0.0
# EX_ribflv_e
# SA growth: 5.025302583727924
# DP growth: 0.023841417826474753
# EX_gly_e
# SA growth: 5.025302269110168
# DP growth: 0.023848325042465035
# EX_thr__L_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_arg__L_e
# SA growth: 4.975077227267806
# DP growth: 0.0
# EX_lys__L_e
# SA growth: 4.889421896019226
# DP growth: 0.0
# EX_orn_e
# SA growth: 5.001538473679777
# DP growth: 0.0
# EX_k_e
# SA growth: 0.0
# DP growth: 0.0
# EX_pro__L_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_ca2_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_mg2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_mn2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_cobalt2_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_zn2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_succ_e
# SA growth: 5.025290140091337
# DP growth: 0.02411460929108955
# EX_co2_e
# SA growth: 5.025290140091337
# DP growth: 0.02411460929108955
# EX_cu2_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_o2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_glu__L_e
# SA growth: 4.621989166353422
# DP growth: 0.0
# EX_fe2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_fum_e
# SA growth: 5.025290140091377
# DP growth: 0.024114609290208477
# EX_his__L_e
# SA growth: 5.025906363219405
# DP growth: 0.010585855240488535
# EX_ile__L_e
# SA growth: 4.8955880439219674
# DP growth: 0.0
# EX_met__L_e
# SA growth: 5.025318032885619
# DP growth: 0.0235022422174751
# EX_so4_e
# SA growth: 0.0
# DP growth: 0.0
# EX_trp__L_e
# SA growth: 5.025633315723155
# DP growth: 0.01658042482516464
# EX_val__L_e
# SA growth: 5.025719036814095
# DP growth: 0.0146984773560348
# EX_thm_e
# SA growth: 0.0
# DP growth: 0.0
# EX_cys__L_e
# SA growth: 0.0
# DP growth: 0.0
# EX_phe__L_e
# SA growth: 4.870366995579907
# DP growth: 0.0
# EX_na1_e
# SA growth: 0.0
# DP growth: 0.0
# EX_ni2_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_nac_e
# SA growth: 0.0
# DP growth: 0.0
# EX_26dap__M_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_mobd_e
# SA growth: 0.0
# DP growth: 0.41003733678287796
# EX_pyr_e
# SA growth: 4.980558865988173
# DP growth: 0.0
# EX_ser__L_e
# SA growth: 4.642529141647281
# DP growth: 0.0
# EX_urea_e
# SA growth: 5.022518081371391
# DP growth: 0.0

# %%
model = create_community_model(models, [BIOMASS_DP, BIOMASS_SA], weights=[10.,1.])
# Out:
# There are no boundary reactions in this model. Therefore specific types of boundary reactions such as 'exchanges', 'demands' or 'sinks' cannot be identified.

# %%
opt = model.optimize()
print("SA growth: " + str(model.reactions.get_by_id(BIOMASS_SA + "_" + model_SA.id).flux))
print("DP growth: " + str(model.reactions.get_by_id(BIOMASS_DP + "_" + model_DP.id).flux))
# Out:
# SA growth: 3.482229886466535
# DP growth: 0.2859373319534555

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>10.0 Growth_DP_83VPs_KB5 + 1.0 BIOMASS_iYS_wild_type_iYS854 = 6.34160320600109</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>26dap__M_e</td>
#       <td>EX_26dap__M_e</td>
#       <td>0.02769</td>
#       <td>7</td>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <td>4abz_e</td>
#       <td>EX_4abz_e</td>
#       <td>0.0001853</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ala__L_e</td>
#       <td>EX_ala__L_e</td>
#       <td>10</td>
#       <td>3</td>
#       <td>7.60%</td>
#     </tr>
#     <tr>
#       <td>arg__L_e</td>
#       <td>EX_arg__L_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>15.20%</td>
#     </tr>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.01486</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.03405</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>0.01011</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.009374</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cys__L_e</td>
#       <td>EX_cys__L_e</td>
#       <td>0.5508</td>
#       <td>3</td>
#       <td>0.42%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.07272</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fum_e</td>
#       <td>EX_fum_e</td>
#       <td>7.868</td>
#       <td>4</td>
#       <td>7.97%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>15.20%</td>
#     </tr>
#     <tr>
#       <td>glu__L_e</td>
#       <td>EX_glu__L_e</td>
#       <td>10</td>
#       <td>5</td>
#       <td>12.67%</td>
#     </tr>
#     <tr>
#       <td>gly_e</td>
#       <td>EX_gly_e</td>
#       <td>0.2855</td>
#       <td>2</td>
#       <td>0.14%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>his__L_e</td>
#       <td>EX_his__L_e</td>
#       <td>0.236</td>
#       <td>6</td>
#       <td>0.36%</td>
#     </tr>
#     <tr>
#       <td>ile__L_e</td>
#       <td>EX_ile__L_e</td>
#       <td>1.207</td>
#       <td>6</td>
#       <td>1.84%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.6619</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>leu__L_e</td>
#       <td>EX_leu__L_e</td>
#       <td>1.218</td>
#       <td>6</td>
#       <td>1.85%</td>
#     </tr>
#     <tr>
#       <td>lys__L_e</td>
#       <td>EX_lys__L_e</td>
#       <td>1.35</td>
#       <td>6</td>
#       <td>2.05%</td>
#     </tr>
#     <tr>
#       <td>met__L_e</td>
#       <td>EX_met__L_e</td>
#       <td>0.3246</td>
#       <td>5</td>
#       <td>0.41%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.05325</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>0.01313</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mobd_e</td>
#       <td>EX_mobd_e</td>
#       <td>2.438E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>6.954</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nac_e</td>
#       <td>EX_nac_e</td>
#       <td>0.0037</td>
#       <td>6</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>ni2_e</td>
#       <td>EX_ni2_e</td>
#       <td>0.01015</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>20</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>orn_e</td>
#       <td>EX_orn_e</td>
#       <td>10</td>
#       <td>5</td>
#       <td>12.67%</td>
#     </tr>
#     <tr>
#       <td>phe__L_e</td>
#       <td>EX_phe__L_e</td>
#       <td>0.7531</td>
#       <td>9</td>
#       <td>1.72%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>7.756</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pro__L_e</td>
#       <td>EX_pro__L_e</td>
#       <td>0.06121</td>
#       <td>5</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>pyr_e</td>
#       <td>EX_pyr_e</td>
#       <td>10</td>
#       <td>3</td>
#       <td>7.60%</td>
#     </tr>
#     <tr>
#       <td>ribflv_e</td>
#       <td>EX_ribflv_e</td>
#       <td>0.001163</td>
#       <td>17</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>ser__L_e</td>
#       <td>EX_ser__L_e</td>
#       <td>10</td>
#       <td>3</td>
#       <td>7.60%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.02057</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>thm_e</td>
#       <td>EX_thm_e</td>
#       <td>0.001615</td>
#       <td>12</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>thr__L_e</td>
#       <td>EX_thr__L_e</td>
#       <td>0.07025</td>
#       <td>4</td>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <td>trp__L_e</td>
#       <td>EX_trp__L_e</td>
#       <td>0.06916</td>
#       <td>11</td>
#       <td>0.19%</td>
#     </tr>
#     <tr>
#       <td>urea_e</td>
#       <td>EX_urea_e</td>
#       <td>10</td>
#       <td>1</td>
#       <td>2.53%</td>
#     </tr>
#     <tr>
#       <td>val__L_e</td>
#       <td>EX_val__L_e</td>
#       <td>1.399</td>
#       <td>5</td>
#       <td>1.77%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>0.01024</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>2fe1s_c_iYS854</td>
#       <td>SK_2fe1s_c_iYS854</td>
#       <td>0.0009506</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>apoACP_c_iYS854</td>
#       <td>SK_apoACP_c_iYS854</td>
#       <td>0.268</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mql8_c_DP_83VPs_KB5</td>
#       <td>Sink_mql8_DP_83VPs_KB5</td>
#       <td>2.769E-05</td>
#       <td>51</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5drib_c_iYS854</td>
#       <td>DM_5drib_c_iYS854</td>
#       <td>-0.003134</td>
#       <td>5</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>amob_c_iYS854</td>
#       <td>DM_amob_c_iYS854</td>
#       <td>-6.964E-06</td>
#       <td>15</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-84.66</td>
#       <td>1</td>
#       <td>32.39%</td>
#     </tr>
#     <tr>
#       <td>etoh_e</td>
#       <td>EX_etoh_e</td>
#       <td>-40.91</td>
#       <td>2</td>
#       <td>31.31%</td>
#     </tr>
#     <tr>
#       <td>for_e</td>
#       <td>EX_for_e</td>
#       <td>-36.87</td>
#       <td>1</td>
#       <td>14.11%</td>
#     </tr>
#     <tr>
#       <td>glyclt_e</td>
#       <td>EX_glyclt_e</td>
#       <td>-0.001738</td>
#       <td>2</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2s_e</td>
#       <td>EX_h2s_e</td>
#       <td>-0.1781</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>-57.42</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ptrc_e</td>
#       <td>EX_ptrc_e</td>
#       <td>-14.43</td>
#       <td>4</td>
#       <td>22.09%</td>
#     </tr>
#     <tr>
#       <td>ahcys_c_iYS854</td>
#       <td>SK_ahcys_c_iYS854</td>
#       <td>-0.0172</td>
#       <td>14</td>
#       <td>0.09%</td>
#     </tr>
#   </tbody>
# </table>

# %%
x2 =[]
y2 =[]
z2 =[]
for met, f in model.medium.items():
    with model:
        medium = model.medium 
        medium[met] = 0
        model.medium = medium
        model.optimize()
        print(met)
        print("SA growth: " + str(model.reactions.get_by_id(BIOMASS_SA + "_" + model_SA.id).flux))
        print("DP growth: " + str(model.reactions.get_by_id(BIOMASS_DP + "_" + model_DP.id).flux))
        for j in range(len(Des)):
            ide = "EX_" + str(Des.iloc[j][1]) + "_e"
            if ide == met:
                x2.append(str(Des.iloc[j][0]))
                y2.append(round(model.reactions.get_by_id(BIOMASS_SA + "_" + model_SA.id).flux,3))
                z2.append(round(model.reactions.get_by_id(BIOMASS_DP + "_" + model_DP.id).flux,3))
# Out:
# EX_glc__D_e
# SA growth: 3.141874771171121
# DP growth: 0.0
# EX_h2o_e
# SA growth: 3.3238890139531394
# DP growth: 0.28593733195345966
# EX_leu__L_e
# SA growth: 3.4370704937175987
# DP growth: 0.28593733195345916
# EX_4abz_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_ala__L_e
# SA growth: 3.482229886466538
# DP growth: 0.28593733195345744
# EX_cl_e
# SA growth: 0.0
# DP growth: 0.0
# EX_pi_e
# SA growth: 3.360272758197507
# DP growth: 0.28593733195345816
# EX_ribflv_e
# SA growth: 3.4811003335280084
# DP growth: 0.28593733195345966
# EX_gly_e
# SA growth: 3.486375784081645
# DP growth: 0.2819130199085781
# EX_thr__L_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_arg__L_e
# SA growth: 3.382449276495586
# DP growth: 0.2859373319534591
# EX_lys__L_e
# SA growth: 3.307856330722536
# DP growth: 0.2859373319534582
# EX_orn_e
# SA growth: 3.351995190806577
# DP growth: 0.2859373319534597
# EX_k_e
# SA growth: 0.0
# DP growth: 0.0
# EX_pro__L_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_ca2_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_mg2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_mn2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_cobalt2_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_zn2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_succ_e
# SA growth: 3.482229886466532
# DP growth: 0.28593733195345905
# EX_co2_e
# SA growth: 3.482229886466532
# DP growth: 0.28593733195345905
# EX_cu2_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_o2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_glu__L_e
# SA growth: 2.9620989099883577
# DP growth: 0.28593733195346926
# EX_fe2_e
# SA growth: 0.0
# DP growth: 0.0
# EX_fum_e
# SA growth: 3.482229886466536
# DP growth: 0.2859373319534493
# EX_his__L_e
# SA growth: 3.42294252967248
# DP growth: 0.28593733195344884
# EX_ile__L_e
# SA growth: 3.3111855218780124
# DP growth: 0.2859373319534545
# EX_met__L_e
# SA growth: 3.477809016355047
# DP growth: 0.28593733195344884
# EX_so4_e
# SA growth: 0.0
# DP growth: 0.0
# EX_trp__L_e
# SA growth: 3.4479074989033505
# DP growth: 0.2859373319534586
# EX_val__L_e
# SA growth: 3.4485739536667572
# DP growth: 0.285937331953459
# EX_thm_e
# SA growth: 0.0
# DP growth: 0.0
# EX_cys__L_e
# SA growth: 0.0
# DP growth: 0.0
# EX_phe__L_e
# SA growth: 3.2560867950099546
# DP growth: 0.28593733195346016
# EX_na1_e
# SA growth: 0.0
# DP growth: 0.0
# EX_ni2_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_nac_e
# SA growth: 0.0
# DP growth: 0.0
# EX_26dap__M_e
# SA growth: 5.026388539834129
# DP growth: 0.0
# EX_mobd_e
# SA growth: 0.0
# DP growth: 0.4100373367828718
# EX_pyr_e
# SA growth: 3.3066673990498217
# DP growth: 0.28593733195344717
# EX_ser__L_e
# SA growth: 3.094586229259937
# DP growth: 0.28593733195344717
# EX_urea_e
# SA growth: 3.3780421299386
# DP growth: 0.28593733195339494

# %%
# Draw plot
title_font = {'fontname':'Arial', 'size':'12', 'color':'black', 'weight':'normal'} 
fig = plt.figure(figsize=(10,5), dpi= 160)

plt.scatter(x = x1, y = y1, color="darkgoldenrod",s=5, marker="^")
plt.scatter(x = x1, y = z1, color="green",s=3, marker="o")
plt.scatter(x = x2, y = y2, color="darkgoldenrod",s=40, marker="^")
plt.scatter(x = x2, y = z2, color="green",s=20, marker="o")
plt.ylim(-0.2,6)     
plt.legend(["$\it{S.aureus}$ with weight 1:1" , "$\it{D. pigrum}$ with weight 1:1", "$\it{S.aureus}$ with weight 1:10" , "$\it{D. pigrum}$ with weight 1:10"], loc=8, bbox_to_anchor=(0.5, 0.13))

# Decorations    
plt.title('The effect of removing each single metabolite from the integrated community on the growth with defined media SNM', **title_font)

plt.xticks(x1,rotation=90)
plt.grid(linestyle='--', alpha=0.5)
plt.ylabel("Growth of $\it{S.aureus}$ and $\it{D. pigrum}$ in the community")
#fig.tight_layout()

plt.savefig("Integrated_community_remove_metabolite_growth_effect_media_SNM.pdf", bbox_inches='tight', dpi=1000) 
plt.show()

# %%
len(model.medium)
# Out:
# 44

# %%
model.medium
# Out:
# {'EX_glc__D_e': 10.0,
#  'EX_h2o_e': 10.0,
#  'EX_leu__L_e': 10.0,
#  'EX_4abz_e': 10.0,
#  'EX_ala__L_e': 10.0,
#  'EX_cl_e': 10.0,
#  'EX_pi_e': 10.0,
#  'EX_ribflv_e': 10.0,
#  'EX_gly_e': 10.0,
#  'EX_thr__L_e': 10.0,
#  'EX_arg__L_e': 10.0,
#  'EX_lys__L_e': 10.0,
#  'EX_orn_e': 10.0,
#  'EX_k_e': 10.0,
#  'EX_pro__L_e': 10.0,
#  'EX_ca2_e': 10.0,
#  'EX_mg2_e': 10.0,
#  'EX_mn2_e': 10.0,
#  'EX_cobalt2_e': 10.0,
#  'EX_zn2_e': 10.0,
#  'EX_succ_e': 10.0,
#  'EX_co2_e': 10.0,
#  'EX_cu2_e': 10.0,
#  'EX_o2_e': 20.0,
#  'EX_glu__L_e': 10.0,
#  'EX_fe2_e': 0.1,
#  'EX_fum_e': 10.0,
#  'EX_his__L_e': 10.0,
#  'EX_ile__L_e': 10.0,
#  'EX_met__L_e': 10.0,
#  'EX_so4_e': 10.0,
#  'EX_trp__L_e': 10.0,
#  'EX_val__L_e': 10.0,
#  'EX_thm_e': 10.0,
#  'EX_cys__L_e': 10.0,
#  'EX_phe__L_e': 10.0,
#  'EX_na1_e': 10.0,
#  'EX_ni2_e': 10.0,
#  'EX_nac_e': 10.0,
#  'EX_26dap__M_e': 10.0,
#  'EX_mobd_e': 10.0,
#  'EX_pyr_e': 10.0,
#  'EX_ser__L_e': 10.0,
#  'EX_urea_e': 10.0}
